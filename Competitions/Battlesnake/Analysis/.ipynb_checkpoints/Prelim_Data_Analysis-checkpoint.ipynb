# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %% [markdown]
# Open data

# %%
df_0 = pd.read_csv('../DATA/stats_0.txt')
df_1 = pd.read_csv('../DATA/stats_1.txt')
df_2 = pd.read_csv('../DATA/stats_2.txt')
df_3 = pd.read_csv('../DATA/stats_3.txt')
df_4 = pd.read_csv('../DATA/stats_4.txt')

# %% [markdown]
# Get steps and episode lengths

# %%
steps_0 = df_0['Env_Steps']
Ep_len_0 = df_0['Avg_EPLM']

steps_1 = df_1['Env_Steps']
Ep_len_1 = df_1['Avg_EPLM']

steps_2 = df_2['Env_Steps']
Ep_len_2 = df_2['Avg_EPLM']

steps_3 = df_3['Env_Steps']
Ep_len_3 = df_3['Avg_EPLM']

steps_4 = df_4['Env_Steps']
Ep_len_4 = df_4['Avg_EPLM']

# %% [markdown]
# Plot

# %%
plt.figure(figsize=(14,7))
plt.plot(steps_0, Ep_len_0, label='Base')
plt.plot(steps_1, Ep_len_1, label='Food Reward Smaller')
plt.plot(steps_2, Ep_len_2, label='More NN params')
plt.plot(steps_3, Ep_len_3, label='Smaller CNN windows')
plt.plot(steps_4, Ep_len_4, label='Discount Factor Reduced')
plt.xlabel('Environment Steps')
plt.ylabel('Average Episode Length')
plt.grid()
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# Compare average episode lengths after 3 million steps

# %%
Ep_len_0[steps_0>3000000].mean()
# Out:
# 64.86500024795532

# %%
Ep_len_1[steps_1>3000000].mean()
# Out:
# 64.3159998512268

# %%
Ep_len_2[steps_2>3000000].mean()
# Out:
# 74.89

# %%
Ep_len_3[steps_3>3000000].mean()
# Out:
# 96.99800003051757

# %%
Ep_len_4[steps_4>3000000].mean()
# Out:
# 73.58500003814697

# %% [markdown]
# More neural network parameters is better. CNN windows need to be modified.
